# %%
import re
import string

# %%
author_gene_file = 'SOM_Faculty.tsv'

# %%
f = open(author_gene_file,'r')
contents = [line.strip().split(',') for line in f]

# %%
for line in contents:
    author = line[0]
    try:
        genes = [(line[ind].strip().translate(None,'[(\"'),line[ind+1].strip().translate(None,'])"')) for ind in range(1,len(test[1:]),2)]
    except IndexError:
        continue
    #genes = [(item[0].translate(None,'[(\"'),item[1].strip().replace(')','')) for item in genes]
    print genes
    print '============================================'
# Out:
# [("'HMGB1'", '0.222222'), ("'TLR4'", '0.122222'), ("'IRF-1'", '0.1'), ("'TNF-alpha'", '0.044444'), ("'alpha-GalCer'", '0.033333'), ("'A2AR'", '0.033333'), ("'JNK'", '0.033333'), ("'IL-13 neutralizing antibody'", '0.022222'), ("'nitric oxide synthase'", '0.022222'), ("'IL-6'", '0.022222'), ("'IRF-1 mRNA'", '0.022222'), ("'iNOS'", '0.022222'), ("'IL-13'", '0.022222'), ("'IFN-gamma'", '0.022222'), ("'SH58261 diminished alpha'", '0.011111'), ("'IL-1R'", '0.011111'), ("'MAP kinase c-Jun NH2)-terminal kinase'", '0.011111'), ("'IRF-1 gene'", '0.011111'), ("'arginase'", '0.011111'), ("'calmodulin'", '0.011111'), ("'High-mobility group box 1'", '0.011111'), ("'Interferon IFN) regulatory factor-1'", '0.011111'), ("'ROS'", '0.011111'), ("'glycolipid antigen alpha-galactosylceramide'", '0.011111'), ("'nuclear protein high-mobility group box 1'", '0.011111'), ("'adenosine A2AR'", '0.011111'), ("'CD1d'", '0.011111'), ("'CaMK'", '0.011111'), ("'adenosine A2A receptor'", '0.011111'), ("'High mobilit
# ...

# %%
c = [('BRAF', 0.111111), ('erbB', 0.074074), ('EphA2', 0.061728), ('CTLA-4', 0.049383), ('LDH', 0.037037), ('LDH isoenzymes', 0.037037), ('serum LDH', 0.024691), ('EGFR', 0.024691), ('IFN', 0.024691), ('ERK', 0.024691), ('erbB family', 0.024691), ('CTLA-4 blockade', 0.024691), ('RRP', 0.024691), ('interferon', 0.012346), ('erbB kinase', 0.012346), ('MAP kinase', 0.012346), ('AKT', 0.012346), (""RRP'"", 0.012346), ('EGF', 0.012346), ('RAF', 0.012346), ('BRAF mutant', 0.012346), ('neuregulin', 0.012346), ('viral T antigen', 0.012346), ('NSG', 0.012346), ('six CTLA-4', 0.012346), ('serum LDH isoenzymes', 0.012346), ('RAS', 0.012346), ('NOD scid gamma', 0.012346), ('epidermal growth factor receptor', 0.012346), ('Multi', 0.012346), ('RRPs', 0.012346), ('GM-CSF', 0.012346), ('PI3K', 0.012346), ('VP2 gene transcripts nor VP1 protein', 0.012346), ('Serum lactate dehydrogenase', 0.012346), ('V600K', 0.012346), ('erbB4', 0.012346), ('MCT4', 0.012346), ('interferon alfa-2b', 0.012346), ('erbB ligands', 0.012346), ('MCT1', 0.012346), ('erbB2', 0.012346), ('erbB3', 0.012346), ('Neuregulin 3 and neuregulin 4', 0.012346), ('monocarboxylate transporters (MCT) 1', 0.012346), ('granulocyte-macrophage colony-stimulating factor', 0.012346), ('interferon treatment benefits', 0.012346), ('MEK', 0.012346), ('tyrosine kinase', 0.012346), ('High-dose interferon', 0.012346)]
# Out:
#   File "<ipython-input-31-786484e2ebc0>", line 1
# ...

# %%
test = contents[1].split(',')
auth = test[0]
genes = [(test[ind],test[ind+1]) for ind in range(1,len(test[1:]))]

# %%
range(1,10,2)
# Out:
# [1, 3, 5, 7, 9]

# %%
genes[0][1].strip().replace(')','')
# Out:
# '0.222222'

# %%
genes[0][0].translate(None,'[(\"')
# Out:
# "'HMGB1'"

# %% [raw]
# contents[1]

# %%
'abcd^7&#342'.translate(None,'^&')
# Out:
# 'abcd7#342'

# %%
import random

# %%
random.sample(5,(1,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-146cfaf77639> in <module>()
# ----> 1 random.sample(5,(1,10))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/random.pyc in sample(self, population, k)
#     319         # set and it doesn't suffer from frequent reselections.
#     320
# --> 321         n = len(population)
#     322         if not 0 <= k <= n:
#     323             raise ValueError("sample larger than population")
#
# TypeError: object of type 'int' has no len()
